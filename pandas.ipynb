# %% [markdown]
# pandas libray:
# useful for data processing and analysis
# pandas data frame:
# pandas dataframe is two dimensional tabular data structure with labeled axes(rows and columns)

# %%
import pandas as pd
import numpy as np

# %%
import pandas as pd
diabetes_df=pd.read_csv('/content/diabetes.csv')

# %%
type(diabetes_df)
# Out:
# pandas.core.frame.DataFrame

# %%
diabetes_df.head()
diabetes_df.shape
# Out:
# (768, 9)

# %% [markdown]
# Loading a data from a pandas dataframe
# pd.read_excel('file path')

# %% [markdown]
# Exporting a data frame to  a csv file

# %% [markdown]
# Exporting the pandas dataframe to an excel file
# df.to_excel('filename')

# %%
#creating  a dataframe with random values
random_df=pd.DataFrame(np.random.rand(20,10))

# %%
random_df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.388565  0.669122  0.519867  0.526586  0.633950  0.638958  0.520110
# 1  0.291809  0.613046  0.161050  0.378370  0.522678  0.417553  0.518049
# 2  0.954142  0.577741  0.930673  0.121689  0.972805  0.578425  0.459148
# 3  0.709753  0.161707  0.105738  0.184224  0.549811  0.670283  0.520221
# 4  0.768806  0.416328  0.850585  0.601934  0.159783  0.034799  0.054195
#
#           7         8         9
# 0  0.847711  0.047508  0.588239
# 1  0.689234  0.918115  0.975882
# 2  0.258596  0.424945  0.452140
# 3  0.291277  0.633930  0.868791
# 4  0.912006  0.340052  0.419205

# %%
random_df.shape
# Out:
# (20, 10)

# %%
#finding no of rows and columns
#boston_df.shape
#printing 1 st 5 rows
#boston_df.head()
#finding last five rows
#boston_df.tail()
#information about df
#boston_df.info()
#finding the number of missing values
#boston_df.isnull().sum()
#removing a row
#boston_df.drop(index=0,axis=0)// u hve to give axis as 0
#drop a column
#boston_df.drop(columns='ZN',axis=1)
#locating a row using the index value
#boston_df.iloc[2]
#locating a particular column

# %%
diabetes_df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
#counting the values based on the labels
diabetes_df.value_counts('Outcome')
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
#group the values based on the mean
diabetes_df.groupby('Outcome').mean()
# Out:
#          Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# Outcome
# 0           3.298000  109.980000      68.184000      19.664000   68.792000
# 1           4.865672  141.257463      70.824627      22.164179  100.335821
#
#                BMI  DiabetesPedigreeFunction        Age
# Outcome
# 0        30.304200                  0.429734  31.190000
# 1        35.142537                  0.550500  37.067164

# %% [markdown]
# Statistical measure

# %%
#locating a particular column
#print(boston_df.iloc[:,0])--->first column
#print(boston_df.iloc[:,1])--->second  column
#print(boston_df.iloc[:,-1])--->last column
#correlation
#1.positive correlation-- one value increase other also increases
#2.negative correlation--one increases other decreses
#boston_df.corr()
